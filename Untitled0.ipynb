# %%
# !unzip '/content/Test protype.zip'
# Out:
# Archive:  /content/Test protype.zip
#    creating: Test protype/Pneumonia Negative/
#   inflating: Test protype/Pneumonia Negative/IM-0304-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0305-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0306-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0307-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0308-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0309-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0311-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0312-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0313-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0314-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0315-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0316-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0317-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0318-0001.jpeg
#   inflating: Test protype/Pneumonia Negative/IM-0319-0001.jpeg
#    creating: Test protype/Pneumonia Positive/
#   inflating: Test protype/Pneumonia Positive/person1035_virus_1729.jpeg
#   inflating: Test protype/Pneumonia Positive/person1036_bacteria_2970.jpeg
#   inflating: Test protype/Pneumonia Positive/person1036_virus_1730.jpeg
#   inflating: Test protype/Pneumonia Positive/person1037_bacteria_2971.jpeg
#   inflating: Test protype/Pneumonia Positive/person1038_bacteria_2972.jpeg
#   inflating: Test protype/Pneumonia Positive/person1038_virus_1733.jpeg
#   inflating: Test protype/Pneumonia Positive/person1039_bacteria_2973.jpeg
#   inflating: Test protype/Pneumonia Positive/person104_bacteria_491.jpeg
#   inflating: Test protype/Pneumonia Positive/person104_bacteria_492.jpeg
#   inflating: Test protype/Pneumonia Positive/person104_virus_191.jpeg
#   inflating: Test protype/Pneumonia Positive/person1040_bacteria_2974.jpeg
#   inflating: Test protype/Pneumonia Positive/person1040_virus_1735.jpeg
#   inflating: Test protype/Pneumonia Positive/person1041_bacteria_2975.jpeg
#   inflating: Test protype/Pneumonia Positive/person1041_virus_1736.jpeg
#   inflating: Test protype/Pneumonia Positive/person1042_virus_1737.jpeg

# %%
# !unzip '/content/Train Prototype dataset.zip'
# Out:
# Archive:  /content/Train Prototype dataset.zip
#    creating: Train Prototype dataset/Pneumonia Negative/
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0001-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0003-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0005-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0006-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0007-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0009-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0010-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0011-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0011-0001-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0011-0001-0002.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0013-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0015-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0016-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0017-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0019-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0021-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0022-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0023-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0025-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0027-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0028-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0029-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0030-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0031-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0033-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0033-0001-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0033-0001-0002.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0035-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0036-0001.jpeg
#   inflating: Train Prototype dataset/Pneumonia Negative/IM-0037-0001.jpeg
#    creating: Train Prototype dataset/Pneumonia Positive/
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_bacteria_1.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_bacteria_2.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_11.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_12.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_13.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_6.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_7.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_8.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1_virus_9.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person10_bacteria_43.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person10_virus_35.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_475.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_477.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_478.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_479.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_480.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_481.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_bacteria_482.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person100_virus_184.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1000_bacteria_2931.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1000_virus_1681.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1001_bacteria_2932.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1002_bacteria_2933.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1003_bacteria_2934.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1003_virus_1685.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1004_bacteria_2935.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1004_virus_1686.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1005_bacteria_2936.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1005_virus_1688.jpeg
#   inflating: Train Prototype dataset/Pneumonia Positive/person1006_bacteria_2937.jpeg

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.models import Sequential
from keras import optimizers

img_width, img_height = 244, 244

num_classes = 2

batch_size = 32
epochs = 30

np.random.seed(123)

datagenerator = ImageDataGenerator(rescale = 1./255)
  
train_generator = datagenerator.flow_from_directory(
                  'Train',
                  target_size =(244, 244),  # target_size = input image size
                  batch_size = 20,
                  class_mode ='binary')
  
  
test_generator = datagenerator.flow_from_directory(
                    'Test',
                    target_size =(244, 244),
                    batch_size = 20,
                    class_mode ='binary')
# Out:
# Found 60 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.

# %%
def plot(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']
  epochs = range(1, len(loss) + 1)
  plt.plot(epochs, loss, 'y', label='Training loss')
  plt.plot(epochs, val_loss, 'r', label='Validation loss')
  plt.title('Training and validation loss')
  plt.xlabel('Epochs')
  plt.ylabel('Loss')
  plt.legend()
  plt.show()


  acc = history.history['accuracy']  #Use accuracy if acc doesn't work
  val_acc = history.history['val_accuracy']  #Use val_accuracy if acc doesn't work
  plt.plot(epochs, acc, 'y', label='Training acc')
  plt.plot(epochs, val_acc, 'r', label='Validation acc')
  plt.title('Training and validation accuracy')
  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.legend()
  plt.show()

# %%
# Set up the model
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(img_width, img_height, 3)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))

model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
history = model.fit(
    train_generator,
    epochs=epochs,
    validation_data=test_generator,
    verbose=1
)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 29s 8s/step - loss: 24.1346 - accuracy: 0.5000 - val_loss: 18.0919 - val_accuracy: 0.5000
# Epoch 2/30
# 3/3 [==============================] - 16s 5s/step - loss: 6.9814 - accuracy: 0.5833 - val_loss: 2.6976 - val_accuracy: 0.5000
# Epoch 3/30
# 3/3 [==============================] - 16s 6s/step - loss: 2.5121 - accuracy: 0.6833 - val_loss: 3.0078 - val_accuracy: 0.5000
# Epoch 4/30
# 3/3 [==============================] - 18s 7s/step - loss: 0.3094 - accuracy: 0.8333 - val_loss: 0.5621 - val_accuracy: 0.7333
# Epoch 5/30
# 3/3 [==============================] - 17s 6s/step - loss: 0.1174 - accuracy: 0.9667 - val_loss: 1.9469 - val_accuracy: 0.5000
# Epoch 6/30
# 3/3 [==============================] - 16s 6s/step - loss: 0.1578 - accuracy: 0.9500 - val_loss: 0.7809 - val_accuracy: 0.6000
# Epoch 7/30
# 3/3 [==============================] - 17s 6s/step - loss: 0.0899 - accuracy: 0.9833 - val_loss: 1.0749 - val_accuracy: 0.5667
# Epoch 8/30
# 3/3 [==============================] - 17s 6s/step - loss: 0.0489 - accuracy: 0.9833 - val_loss: 0.6795 - val_accuracy: 0.6667
# Epoch 9/30
# 3/3 [==============================] - 17s 6s/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.3915 - val_accuracy: 0.7667
# Epoch 10/30
# 3/3 [==============================] - 17s 6s/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 2.1270 - val_accuracy: 0.5333
# Epoch 11/30
# 3/3 [==============================] - 18s 6s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.5510 - val_accuracy: 0.7000
# Epoch 12/30
# 3/3 [==============================] - 16s 6s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 2.2887 - val_accuracy: 0.5333
# Epoch 13/30
# 3/3 [==============================] - 17s 6s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.2052 - val_accuracy: 0.5333
# Epoch 14/30
# 3/3 [==============================] - 17s 6s/step - loss: 7.2707e-04 - accuracy: 1.0000 - val_loss: 1.4102 - val_accuracy: 0.6667
# Epoch 15/30
# 3/3 [==============================] - 16s 6s/step - loss: 6.1012e-04 - accuracy: 1.0000 - val_loss: 1.1723 - val_accuracy: 0.6667
# Epoch 16/30
# 3/3 [==============================] - 17s 6s/step - loss: 2.9295e-04 - accuracy: 1.0000 - val_loss: 1.8363 - val_accuracy: 0.6000
# Epoch 17/30
# 3/3 [==============================] - 17s 6s/step - loss: 1.3155e-04 - accuracy: 1.0000 - val_loss: 2.1683 - val_accuracy: 0.5667
# Epoch 18/30
# 3/3 [==============================] - 18s 6s/step - loss: 1.2066e-04 - accuracy: 1.0000 - val_loss: 2.2927 - val_accuracy: 0.5667
# Epoch 19/30
# 3/3 [==============================] - 17s 6s/step - loss: 1.0363e-04 - accuracy: 1.0000 - val_loss: 2.3337 - val_accuracy: 0.5667
# Epoch 20/30
# 3/3 [==============================] - 17s 6s/step - loss: 8.0715e-05 - accuracy: 1.0000 - val_loss: 2.3292 - val_accuracy: 0.5667
# Epoch 21/30
# 3/3 [==============================] - 16s 6s/step - loss: 6.1290e-05 - accuracy: 1.0000 - val_loss: 2.2873 - val_accuracy: 0.5667
# Epoch 22/30
# 3/3 [==============================] - 16s 6s/step - loss: 5.1611e-05 - accuracy: 1.0000 - val_loss: 2.2138 - val_accuracy: 0.6000
# Epoch 23/30
# 3/3 [==============================] - 17s 6s/step - loss: 4.5354e-05 - accuracy: 1.0000 - val_loss: 2.1416 - val_accuracy: 0.6000
# Epoch 24/30
# 3/3 [==============================] - 17s 6s/step - loss: 3.8919e-05 - accuracy: 1.0000 - val_loss: 2.0995 - val_accuracy: 0.6000
# Epoch 25/30
# 3/3 [==============================] - 17s 6s/step - loss: 3.5313e-05 - accuracy: 1.0000 - val_loss: 2.0802 - val_accuracy: 0.6000
# Epoch 26/30
# 3/3 [==============================] - 16s 6s/step - loss: 3.1836e-05 - accuracy: 1.0000 - val_loss: 2.0948 - val_accuracy: 0.6000
# Epoch 27/30
# 3/3 [==============================] - 16s 6s/step - loss: 2.8825e-05 - accuracy: 1.0000 - val_loss: 2.1260 - val_accuracy: 0.6000
# Epoch 28/30
# 3/3 [==============================] - 16s 6s/step - loss: 2.5388e-05 - accuracy: 1.0000 - val_loss: 2.1665 - val_accuracy: 0.6000
# Epoch 29/30
# 3/3 [==============================] - 17s 6s/step - loss: 2.2489e-05 - accuracy: 1.0000 - val_loss: 2.1965 - val_accuracy: 0.6000
# Epoch 30/30
# 3/3 [==============================] - 16s 5s/step - loss: 2.0107e-05 - accuracy: 1.0000 - val_loss: 2.1971 - val_accuracy: 0.6000

# %%
plot(history)
